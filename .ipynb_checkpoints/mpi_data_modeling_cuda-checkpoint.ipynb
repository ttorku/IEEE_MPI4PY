# %% [markdown]
# ### CSCI 6330
# ### Group Members: Thomas, Ahmeed, Eben, Tingting

# %% [markdown]
# ### Data preprocessing without MPI

# %%
#import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from time import process_time    #checking cpu time
from sklearn.preprocessing import MinMaxScaler   #for scaling data
#specify the scaling type
scaler =MinMaxScaler()
#get the start time
import sys
sys.path.insert(0, '../../Utilities/')
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
c_dir =os.getcwd()
path = '/Figures/'   #for sir models
out = c_dir +path
if not os.path.exists(out):
    os.makedirs(out)


#load the data
data =pd.read_csv("tndata.csv")

#define the preprocess function
def data_process(data, scaler, cs ="yes"):
    #reverse index
    tdata=data.reindex(index=data.index[::-1])
    #get the infected 
    I=tdata['TOTAL_CONFIRMED']
    #get the recovered
    R =tdata['TOTAL_INACTIVE_RECOVERED']
    #get the length of the data
    nn =len(I)
    # show whether want to scaling
    if cs =="yes": ##indicate yes
        tt=np.linspace(0,nn, nn)
        y1 =np.array(I[:nn]).reshape((-1,1))
        y2 =np.array(R[:nn]).reshape((-1,1))
        #scaling
        II =scaler.fit_transform(y1)
        RR =scaler.fit_transform(y2)
        #plot
        plt.plot(tt, II, '--r')
        plt.plot(tt, RR, '--b')
        plt.legend(['Infected', 'Recovered'])
        plt.title('Scaled Data') 
        plt.show()
    else:  ##indicate no
        tt=np.linspace(0,nn, nn)
        II =np.array(I[:nn]).reshape((-1,1))
        RR =np.array(R[:nn]).reshape((-1,1))
        #plot
        plt.plot(tt, II, '--r')
        plt.plot(tt, RR, '--b')
        plt.legend(['Infected', 'Recovered'])
        plt.title('UnScaled Data') 
        plt.show()    
    return tt, II, RR

# %%
start =process_time()
tt, II, RR=data_process(data, scaler, "yes")  #scaled

stop = process_time()
print("++++++++++++++++++Data Processing without MPI+++++++++++++++++++++++\n")
print("CPU time for data preprocessing in seconds:",stop-start)
# Out:
# ++++++++++++++++++Data Processing without MPI+++++++++++++++++++++++
#
# CPU time for data preprocessing in seconds: 0.16257008799999983

# %%
start =process_time()
tt, II, RR=data_process(data, scaler, "no")  #unscaled

stop = process_time()
print("++++++++++++++++++Data Processing without MPI+++++++++++++++++++++++\n")
print("CPU time for data preprocessing in seconds:",stop-start)
# Out:
# ++++++++++++++++++Data Processing without MPI+++++++++++++++++++++++
#
# CPU time for data preprocessing in seconds: 0.11682407900000058

# %% [markdown]
# ### Data preprocessing with MPI

# %%
# %%file script.py
#!/usr/bin/env python
from mpi4py import MPI
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from time import process_time    #checking cpu time
from sklearn.preprocessing import MinMaxScaler 
import time

comm = MPI.COMM_WORLD
rank = comm.rank
size = comm.size
name = MPI.Get_processor_name()
if rank == 0:
    #start = process_time()
    tt, II, RR=data_process(data, scaler, "yes")  #scaled
    print("rank0 finished")
#get the start time
# Out:
# Overwriting script.py

# %%
start =process_time()

# !mpiexec  -np 4 python script.py

stop = process_time()

print("++++++++++++++++++Data Processing with MPI+++++++++++++++++++++++\n")
print("CPU time for data preprocessing in seconds:",stop-start)
# Out:
# --------------------------------------------------------------------------
# WARNING: No preset parameters were found for the device that Open MPI
# detected:
#
#   Local host:            hamilton02
#   Device name:           mlx5_0
#   Device vendor ID:      0x02c9
#   Device vendor part ID: 4117
#
# Default device parameters will be used, which may result in lower
# performance.  You can edit any of the files specified by the
# btl_openib_device_param_files MCA parameter to set values for your
# device.
#
# NOTE: You can turn off this warning by setting the MCA parameter
#       btl_openib_warn_no_device_params_found to 0.
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# WARNING: There is at least non-excluded one OpenFabrics device found,
# but there are no active ports detected (or Open MPI was unable to use
# them).  This is most certainly not what you wanted.  Check your
# cables, subnet manager configuration, etc.  The openib BTL will be
# ignored for this job.
#
#   Local host: hamilton02
# --------------------------------------------------------------------------
# Traceback (most recent call last):
#   File "script.py", line 16, in <module>
#     tt, II, RR=data_process(data, scaler, "yes")  #scaled
# NameError: name 'data_process' is not defined
# -------------------------------------------------------
# Primary job  terminated normally, but 1 process returned
# a non-zero exit code.. Per user-direction, the job has been aborted.
# -------------------------------------------------------
# --------------------------------------------------------------------------
# mpiexec detected that one or more processes exited with non-zero status, thus causing
# the job to be terminated. The first process to do so was:
#
#   Process name: [[31066,1],0]
#   Exit code:    1
# --------------------------------------------------------------------------
# [hamilton02:19214] 3 more processes have sent help message help-mpi-btl-openib.txt / no device params found
# [hamilton02:19214] Set MCA parameter "orte_base_help_aggregate" to 0 to see all help / error messages
# [hamilton02:19214] 3 more processes have sent help message help-mpi-btl-openib.txt / no active ports found
# ++++++++++++++++++Data Processing with MPI+++++++++++++++++++++++
#
# CPU time for data preprocessing in seconds: 0.10295176400000017

# %%
# %%file script1.py
#!/usr/bin/env python
from mpi4py import MPI
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from time import process_time    #checking cpu time
from sklearn.preprocessing import MinMaxScaler 
import time

comm = MPI.COMM_WORLD
rank = comm.rank
size = comm.size
name = MPI.Get_processor_name()
if rank == 0:
    #start = process_time()
    tt, II, RR=data_process(data, scaler, "no")  #unscaled
    print("rank0 finished")
#get the start time
# Out:
# Overwriting script1.py

# %%
start =process_time()

# !mpiexec  -np 4 python script1.py

stop = process_time()

print("++++++++++++++++++Data Processing with MPI+++++++++++++++++++++++\n")
print("CPU time for data preprocessing in seconds:",stop-start)
# Out:
# --------------------------------------------------------------------------
# WARNING: No preset parameters were found for the device that Open MPI
# detected:
#
#   Local host:            hamilton02
#   Device name:           mlx5_0
#   Device vendor ID:      0x02c9
#   Device vendor part ID: 4117
#
# Default device parameters will be used, which may result in lower
# performance.  You can edit any of the files specified by the
# btl_openib_device_param_files MCA parameter to set values for your
# device.
#
# NOTE: You can turn off this warning by setting the MCA parameter
#       btl_openib_warn_no_device_params_found to 0.
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# WARNING: There is at least non-excluded one OpenFabrics device found,
# but there are no active ports detected (or Open MPI was unable to use
# them).  This is most certainly not what you wanted.  Check your
# cables, subnet manager configuration, etc.  The openib BTL will be
# ignored for this job.
#
#   Local host: hamilton02
# --------------------------------------------------------------------------
# Traceback (most recent call last):
#   File "script1.py", line 16, in <module>
#     tt, II, RR=data_process(data, scaler, "no")  #unscaled
# NameError: name 'data_process' is not defined
# -------------------------------------------------------
# Primary job  terminated normally, but 1 process returned
# a non-zero exit code.. Per user-direction, the job has been aborted.
# -------------------------------------------------------
# --------------------------------------------------------------------------
# mpiexec detected that one or more processes exited with non-zero status, thus causing
# the job to be terminated. The first process to do so was:
#
#   Process name: [[32330,1],0]
#   Exit code:    1
# --------------------------------------------------------------------------
# [hamilton02:19486] 3 more processes have sent help message help-mpi-btl-openib.txt / no device params found
# [hamilton02:19486] Set MCA parameter "orte_base_help_aggregate" to 0 to see all help / error messages
# [hamilton02:19486] 3 more processes have sent help message help-mpi-btl-openib.txt / no active ports found
# ++++++++++++++++++Data Processing with MPI+++++++++++++++++++++++
#
# CPU time for data preprocessing in seconds: 0.07536918700000061

# %% [markdown]
# ### Modeling without mpi on CUDA

# %%
from rnn_models_cuda import *
#RNN models
start =process_time()
i_true_l, i_pred_l, _, _, _, _,_, i_loss_l_tr=run_model_cuda(II, 'LSTM', 1500, 128, 500, 0.8) 
i_true_b, i_pred_b, _, _, _, _,_, i_loss_b_tr=run_model_cuda(II, 'BiLSTM', 1500, 128, 500, 0.8)
i_true_g, i_pred_g, _, _, _, _,_, i_loss_g_tr=run_model_cuda(II, 'GRU', 1500, 100, 500, 0.8)

x_t =np.arange(0, len(i_pred_l),1).reshape((-1,1))

plt.plot(x_t, i_true_l, '-o')
plt.plot(x_t, i_pred_l, '--b')
plt.plot(x_t, i_pred_b, '--r')
plt.plot(x_t, i_pred_g, '--c')
plt.legend(['LSTM', 'BiLSTM', 'GRU'])
plt.title('Modeling without mpi on CUDA')
plt.savefig(out+'wompi_cuda.png')
plt.show()

stop = process_time()

print("++++++++++++++++++Modeling Infected Data without MPI on CUDA+++++++++++++++++++++++\n")
print("Time for modeling without MPI on CUDA in seconds:",stop-start)
# Out:
# Tennessee outcomes on CUDA............
# LSTM Training
# Epoch 100/1500, Total Loss: 2.367e-03, Time:0.01 seconds
# Epoch 200/1500, Total Loss: 3.862e-04, Time:0.01 seconds
# Epoch 300/1500, Total Loss: 3.435e-04, Time:0.01 seconds
# Epoch 400/1500, Total Loss: 2.360e-04, Time:0.01 seconds
# Epoch 500/1500, Total Loss: 1.867e-04, Time:0.01 seconds
# Epoch 600/1500, Total Loss: 1.594e-04, Time:0.01 seconds
# Epoch 700/1500, Total Loss: 1.115e-04, Time:0.01 seconds
# Epoch 800/1500, Total Loss: 9.224e-05, Time:0.01 seconds
# Epoch 900/1500, Total Loss: 7.953e-05, Time:0.01 seconds
# Epoch 1000/1500, Total Loss: 8.620e-05, Time:0.01 seconds
# Epoch 1100/1500, Total Loss: 5.495e-05, Time:0.01 seconds
# Epoch 1200/1500, Total Loss: 8.438e-05, Time:0.01 seconds
# Epoch 1300/1500, Total Loss: 4.894e-05, Time:0.01 seconds
# Epoch 1400/1500, Total Loss: 6.274e-05, Time:0.01 seconds
# Epoch 1500/1500, Total Loss: 6.256e-05, Time:0.01 seconds
# LSTM Total Training Time in seconds 17.801517009735107
# Evaluation Time: 0.010301828384399414
# RMSE for LSTM_model(
#   (lstm_out): LSTM(1, 16, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=16, out_features=1, bias=True)
# ): 19768.202858678465
# MAPE for LSTM_model(
#   (lstm_out): LSTM(1, 16, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=16, out_features=1, bias=True)
# ): 0.012895556363936023
# EV for LSTM_model(
#   (lstm_out): LSTM(1, 16, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=16, out_features=1, bias=True)
# ): 0.22352184012493892
# Tennessee outcomes on CUDA............
# BiLSTM Training
# Epoch 100/1500, Total Loss: 1.071e-03, Time:0.02 seconds
# Epoch 200/1500, Total Loss: 4.762e-04, Time:0.02 seconds
# Epoch 300/1500, Total Loss: 3.835e-04, Time:0.02 seconds
# Epoch 400/1500, Total Loss: 2.684e-04, Time:0.02 seconds
# Epoch 500/1500, Total Loss: 1.574e-04, Time:0.02 seconds
# Epoch 600/1500, Total Loss: 1.211e-04, Time:0.02 seconds
# Epoch 700/1500, Total Loss: 8.584e-05, Time:0.02 seconds
# Epoch 800/1500, Total Loss: 8.681e-05, Time:0.02 seconds
# Epoch 900/1500, Total Loss: 5.858e-05, Time:0.02 seconds
# Epoch 1000/1500, Total Loss: 4.687e-05, Time:0.02 seconds
# Epoch 1100/1500, Total Loss: 7.267e-05, Time:0.02 seconds
# Epoch 1200/1500, Total Loss: 3.636e-05, Time:0.02 seconds
# Epoch 1300/1500, Total Loss: 3.530e-05, Time:0.02 seconds
# Epoch 1400/1500, Total Loss: 6.190e-05, Time:0.02 seconds
# Epoch 1500/1500, Total Loss: 2.512e-05, Time:0.02 seconds
# BiLSTM Total Training Time in seconds 23.756154537200928
# Evaluation Time: 0.012507200241088867
# RMSE for BiLSTM_model(
#   (bilstm): LSTM(1, 16, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#   (fc): Linear(in_features=32, out_features=1, bias=True)
# ): 13278.992182987131
# MAPE for BiLSTM_model(
#   (bilstm): LSTM(1, 16, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#   (fc): Linear(in_features=32, out_features=1, bias=True)
# ): 0.00866239553368404
# EV for BiLSTM_model(
#   (bilstm): LSTM(1, 16, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#   (fc): Linear(in_features=32, out_features=1, bias=True)
# ): 0.39485311400835144
# Tennessee outcomes on CUDA............
# GRU Training
# Epoch 100/1500, Total Loss: 6.625e-04, Time:0.02 seconds
# Epoch 200/1500, Total Loss: 3.147e-04, Time:0.02 seconds
# Epoch 300/1500, Total Loss: 2.015e-04, Time:0.02 seconds
# Epoch 400/1500, Total Loss: 2.345e-04, Time:0.02 seconds
# Epoch 500/1500, Total Loss: 1.802e-04, Time:0.02 seconds
# Epoch 600/1500, Total Loss: 3.061e-04, Time:0.02 seconds
# Epoch 700/1500, Total Loss: 8.759e-05, Time:0.02 seconds
# Epoch 800/1500, Total Loss: 7.752e-05, Time:0.02 seconds
# Epoch 900/1500, Total Loss: 7.798e-05, Time:0.02 seconds
# Epoch 1000/1500, Total Loss: 5.977e-05, Time:0.02 seconds
# Epoch 1100/1500, Total Loss: 1.057e-04, Time:0.02 seconds
# Epoch 1200/1500, Total Loss: 3.719e-05, Time:0.02 seconds
# Epoch 1300/1500, Total Loss: 5.570e-05, Time:0.02 seconds
# Epoch 1400/1500, Total Loss: 5.068e-05, Time:0.02 seconds
# Epoch 1500/1500, Total Loss: 3.865e-05, Time:0.02 seconds
# GRU Total Training Time in seconds 33.75155282020569
# Evaluation Time: 0.008746623992919922
# RMSE for GRU_model(
#   (gru): GRU(1, 16, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=16, out_features=1, bias=True)
# ): 6594.664483890942
# MAPE for GRU_model(
#   (gru): GRU(1, 16, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=16, out_features=1, bias=True)
# ): 0.004301952390979657
# EV for GRU_model(
#   (gru): GRU(1, 16, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=16, out_features=1, bias=True)
# ): -0.6514387124077761
# ++++++++++++++++++Modeling Infected Data without MPI on CUDA+++++++++++++++++++++++
#
# Time for modeling without MPI on CUDA in seconds: 77.572993297

# %% [markdown]
# ### Modeling with MPI on CUDA

# %%
# %%file script3.py
#!/usr/bin/env python
from mpi4py import MPI
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from time import process_time    #checking cpu time
from sklearn.preprocessing import MinMaxScaler 
import time
import sys
sys.path.insert(0, '../../Utilities/')
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
c_dir =os.getcwd()
path = '/Figures/'   #for sir models
out = c_dir +path
if not os.path.exists(out):
    os.makedirs(out)
from rnn_models_cuda import *
#load the data
data =pd.read_csv("tndata.csv")
# tt, II, RR =data_process(data,scaler, 'no')
scaler =MinMaxScaler()

#define the preprocess function
def data_process(data, scaler, cs ="yes"):
    #reverse index
    tdata=data.reindex(index=data.index[::-1])
    #get the infected 
    I=tdata['TOTAL_CONFIRMED']
    #get the recovered
    R =tdata['TOTAL_INACTIVE_RECOVERED']
    #get the length of the data
    nn =len(I)
    # show whether want to scaling
    if cs =="yes": ##indicate yes
        tt=np.linspace(0,nn, nn)
        y1 =np.array(I[:nn]).reshape((-1,1))
        y2 =np.array(R[:nn]).reshape((-1,1))
        #scaling
        II =scaler.fit_transform(y1)
        RR =scaler.fit_transform(y2)
        #plot
        plt.plot(tt, II, '--r')
        plt.plot(tt, RR, '--b')
        plt.legend(['Infected', 'Recovered'])
        plt.title('Scaled Data') 
        plt.show()
    else:  ##indicate no
        tt=np.linspace(0,nn, nn)
        II =np.array(I[:nn]).reshape((-1,1))
        RR =np.array(R[:nn]).reshape((-1,1))
        #plot
        plt.plot(tt, II, '--r')
        plt.plot(tt, RR, '--b')
        plt.legend(['Infected', 'Recovered'])
        plt.title('UnScaled Data') 
        plt.show()    
    return tt, II, RR

p=16
comm = MPI.COMM_WORLD
rank = comm.rank
size = comm.size
name = MPI.Get_processor_name()
if rank == 0:
    tt, II, RR =data_process(data,scaler, 'no')
    i_true_l, i_pred_l, _, _, _, _,ep, i_loss_l=run_model_cuda(II, 'LSTM', 1500, 128, 500, 0.8) 
    i_true_b, i_pred_b, _, _, _, _,_, i_loss_b=run_model_cuda(II, 'BiLSTM', 1500, 128, 500, 0.8)
    i_true_g, i_pred_g, _, _, _, _,_, i_loss_g=run_model_cuda(II, 'GRU', 1500, 100, 500, 0.8)
    x_t =np.arange(0, len(i_pred_l),1).reshape((-1,1))
    
    
    plt.plot(x_t, i_true_l, '-o')
    plt.plot(x_t, i_pred_l, '--b')
    plt.plot(x_t, i_pred_b, '--r')
    plt.plot(x_t, i_pred_g, '--c')
    plt.legend(['LSTM', 'BiLSTM', 'GRU'])
    plt.title('Modeling with MPI on CUDA')
    plt.savefig(out+'wmpi_cuda_{}.png'.format(p))
    plt.show()
    print("rank0 finished")
# Out:
# Overwriting script3.py

# %%
start =process_time()

# !mpiexec  -np 16 python script3.py

stop = process_time()

print("++++++++++++++++++Modeling with MPI on CUDA+++++++++++++++++++++++\n")
print("Tme for modeling of Infected Data on CUDA in seconds:",stop-start)
# Out:
# --------------------------------------------------------------------------
# WARNING: No preset parameters were found for the device that Open MPI
# detected:
#
#   Local host:            hamilton02
#   Device name:           mlx5_0
#   Device vendor ID:      0x02c9
#   Device vendor part ID: 4117
#
# Default device parameters will be used, which may result in lower
# performance.  You can edit any of the files specified by the
# btl_openib_device_param_files MCA parameter to set values for your
# device.
#
# NOTE: You can turn off this warning by setting the MCA parameter
#       btl_openib_warn_no_device_params_found to 0.
# --------------------------------------------------------------------------
# --------------------------------------------------------------------------
# WARNING: There is at least non-excluded one OpenFabrics device found,
# but there are no active ports detected (or Open MPI was unable to use
# them).  This is most certainly not what you wanted.  Check your
# cables, subnet manager configuration, etc.  The openib BTL will be
# ignored for this job.
#
#   Local host: hamilton02
# --------------------------------------------------------------------------
# [hamilton02:19988] 15 more processes have sent help message help-mpi-btl-openib.txt / no device params found
# [hamilton02:19988] Set MCA parameter "orte_base_help_aggregate" to 0 to see all help / error messages
# [hamilton02:19988] 15 more processes have sent help message help-mpi-btl-openib.txt / no active ports found
# Figure(640x480)
# Tennessee outcomes on CUDA............
# LSTM Training
# Epoch 100/1500, Total Loss: 2.367e-03, Time:0.02 seconds
# Epoch 200/1500, Total Loss: 3.862e-04, Time:0.02 seconds
# Epoch 300/1500, Total Loss: 3.435e-04, Time:0.02 seconds
# Epoch 400/1500, Total Loss: 2.360e-04, Time:0.01 seconds
# Epoch 500/1500, Total Loss: 1.867e-04, Time:0.02 seconds
# Epoch 600/1500, Total Loss: 1.594e-04, Time:0.02 seconds
# Epoch 700/1500, Total Loss: 1.115e-04, Time:0.01 seconds
# Epoch 800/1500, Total Loss: 9.224e-05, Time:0.02 seconds
# Epoch 900/1500, Total Loss: 7.953e-05, Time:0.02 seconds
# Epoch 1000/1500, Total Loss: 8.620e-05, Time:0.02 seconds
# Epoch 1100/1500, Total Loss: 5.495e-05, Time:0.02 seconds
# Epoch 1200/1500, Total Loss: 8.438e-05, Time:0.02 seconds
# Epoch 1300/1500, Total Loss: 4.894e-05, Time:0.01 seconds
# Epoch 1400/1500, Total Loss: 6.274e-05, Time:0.02 seconds
# Epoch 1500/1500, Total Loss: 6.256e-05, Time:0.02 seconds
# LSTM Total Training Time in seconds 28.046898126602173
# Evaluation Time: 0.014598608016967773
# RMSE for LSTM_model(
#   (lstm_out): LSTM(1, 16, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=16, out_features=1, bias=True)
# ): 19768.202858678465
# MAPE for LSTM_model(
#   (lstm_out): LSTM(1, 16, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=16, out_features=1, bias=True)
# ): 0.012895556363936023
# EV for LSTM_model(
#   (lstm_out): LSTM(1, 16, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=16, out_features=1, bias=True)
# ): 0.22352184012493892
# Tennessee outcomes on CUDA............
# BiLSTM Training
# Epoch 100/1500, Total Loss: 1.071e-03, Time:0.01 seconds
# Epoch 200/1500, Total Loss: 4.762e-04, Time:0.02 seconds
# Epoch 300/1500, Total Loss: 3.835e-04, Time:0.03 seconds
# Epoch 400/1500, Total Loss: 2.684e-04, Time:0.03 seconds
# Epoch 500/1500, Total Loss: 1.574e-04, Time:0.03 seconds
# Epoch 600/1500, Total Loss: 1.211e-04, Time:0.02 seconds
# Epoch 700/1500, Total Loss: 8.584e-05, Time:0.02 seconds
# Epoch 800/1500, Total Loss: 8.681e-05, Time:0.02 seconds
# Epoch 900/1500, Total Loss: 5.858e-05, Time:0.01 seconds
# Epoch 1000/1500, Total Loss: 4.687e-05, Time:0.03 seconds
# Epoch 1100/1500, Total Loss: 7.267e-05, Time:0.03 seconds
# Epoch 1200/1500, Total Loss: 3.636e-05, Time:0.02 seconds
# Epoch 1300/1500, Total Loss: 3.530e-05, Time:0.03 seconds
# Epoch 1400/1500, Total Loss: 6.190e-05, Time:0.03 seconds
# Epoch 1500/1500, Total Loss: 2.512e-05, Time:0.02 seconds
# BiLSTM Total Training Time in seconds 37.087132692337036
# Evaluation Time: 0.012267351150512695
# RMSE for BiLSTM_model(
#   (bilstm): LSTM(1, 16, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#   (fc): Linear(in_features=32, out_features=1, bias=True)
# ): 13278.992182987131
# MAPE for BiLSTM_model(
#   (bilstm): LSTM(1, 16, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#   (fc): Linear(in_features=32, out_features=1, bias=True)
# ): 0.00866239553368404
# EV for BiLSTM_model(
#   (bilstm): LSTM(1, 16, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#   (fc): Linear(in_features=32, out_features=1, bias=True)
# ): 0.39485311400835144
# Tennessee outcomes on CUDA............
# GRU Training
# Epoch 100/1500, Total Loss: 6.625e-04, Time:0.04 seconds
# Epoch 200/1500, Total Loss: 3.147e-04, Time:0.03 seconds
# Epoch 300/1500, Total Loss: 2.015e-04, Time:0.04 seconds
# Epoch 400/1500, Total Loss: 2.345e-04, Time:0.04 seconds
# Epoch 500/1500, Total Loss: 1.802e-04, Time:0.04 seconds
# Epoch 600/1500, Total Loss: 3.061e-04, Time:0.03 seconds
# Epoch 700/1500, Total Loss: 8.759e-05, Time:0.03 seconds
# Epoch 800/1500, Total Loss: 7.752e-05, Time:0.02 seconds
# Epoch 900/1500, Total Loss: 7.798e-05, Time:0.03 seconds
# Epoch 1000/1500, Total Loss: 5.977e-05, Time:0.02 seconds
# Epoch 1100/1500, Total Loss: 1.057e-04, Time:0.05 seconds
# Epoch 1200/1500, Total Loss: 3.719e-05, Time:0.03 seconds
# Epoch 1300/1500, Total Loss: 5.570e-05, Time:0.04 seconds
# Epoch 1400/1500, Total Loss: 5.068e-05, Time:0.03 seconds
# Epoch 1500/1500, Total Loss: 3.865e-05, Time:0.03 seconds
# GRU Total Training Time in seconds 52.46400475502014
# Evaluation Time: 0.007498741149902344
# RMSE for GRU_model(
#   (gru): GRU(1, 16, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=16, out_features=1, bias=True)
# ): 6594.664483890942
# MAPE for GRU_model(
#   (gru): GRU(1, 16, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=16, out_features=1, bias=True)
# ): 0.004301952390979657
# EV for GRU_model(
#   (gru): GRU(1, 16, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=16, out_features=1, bias=True)
# ): -0.6514387124077761
# Figure(640x480)
# rank0 finished
# ++++++++++++++++++Modeling with MPI on CUDA+++++++++++++++++++++++
#
# Tme for modeling of Infected Data on CUDA in seconds: 3.641251581000006

# %%
##plot
xx =np.array([2, 4, 6, 8, 10, 12, 14, 16])
yy =np.array([2.23, 2.28, 2.36, 2.53, 2.64, 2.93, 3.13, 3.52])
plt.plot(xx, yy, '-o')
plt.xlabel('Number of Processors')
plt.ylabel('GPU Time (seconds)')
plt.title('Model Performance')
plt.savefig('gpu_time.png')
plt.show()
